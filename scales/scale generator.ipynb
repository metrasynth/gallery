# %% [markdown]
# # Scale generator for SunVox
#
# This is a series of note translators for SunVox that lock your notes
# into a specific scale.
#
# It requires SunVox 1.9.3 or higher to use, as it makes use of MultiSynth event output.
#
# ## How to use them
#
# Load the sunsynth for the scale you'd like to use.
#
# Send notes to it, via a tracker, MIDI, or from another module.
#
# Connect the scale's output to the input of a synth.
#
# The notes sent to the synth will be locked into the scale you loaded.
#
# ## How it works
#
# [*musthe*](https://github.com/gciruelos/musthe) provides a basic music theory engine. We maintain fork in the same directory as this notebook.
#
# [*Radiant Voices*](https://radiant-voices.readthedocs.io/) lets us construct and write SunVox compatible project files.
#
# The code below goes through all notes and scales available in *musthe*, and creates the structures needed to lock notes into those scales.

# %%
import musthe as m
import rv.api as rv

# %%
def scale_project(root_note, scale_name):
    name = '{} {} scale'.format(root_note, scale_name).replace('_', ' ')
    filename = '{}.sunsynth'.format(name)
    
    scale = m.scale(m.Note(root_note), scale_name=scale_name)
    scale_ids = sorted({n.note_id for n in scale})
    
    proj = rv.Project()
    proj.name = name
    in_mod = proj.new_module(rv.m.MultiSynth, name='I {}'.format(name))
    in_mod.color = (0, 255, 0)
    out_mod = proj.output
    gate_mods = {}
    
    metamod = rv.m.MetaModule(project=proj)
    metamod.input_module = in_mod.index
    metamod.name = proj.name
    
    synth = rv.Synth(metamod)

    def gate_mod(offset):
        if offset not in gate_mods:
            gate = gate_mods[offset] = proj.new_module(
                rv.m.MultiSynth, 
                name='G{} {}'.format(offset, name),
            )
            gate.color = (64, 64, 64)
            if offset > 0:
                transpose = proj.new_module(
                    rv.m.MultiSynth,
                    name='T{} {}'.format(offset, name),
                    transpose=-offset,
                )
                transpose.color = (64, 64, 64)
                in_mod >> gate >> transpose >> out_mod
            else:
                in_mod >> gate >> out_mod
            for x in range(128):
                gate.nv_curve.values[x] = 0
        return gate_mods[offset]

    # Start one octave below to ensure offset is initialized
    # once we get to the note range we care about.
    offset = 0
    for note in range(-12, 128):
        if note % 12 in scale_ids:
            offset = 0
        else:
            offset += 1
        gate = gate_mod(offset)
        if note >= 0:
            gate.nv_curve.values[note] = 255

    proj.in_mod = in_mod
            
    proj.layout(prog='dot')            
    return synth, filename

# %%
for root_note in ['C', 'C#', 'Db', 'D', 'D#', 'Eb', 'E', 'F', 'F#', 'Gb', 'G', 'G#', 'Ab', 'A', 'A#', 'Bb', 'B']:
    root_note_id = m.Note(root_note).note_id
    for scale_name in [
        'major',
        'natural_minor',
        'harmonic_minor',
        'melodic_minor',
        'dorian',
        'locrian',
        'lydian',
        'mixolydian',
        'phrygian',
        'major_pentatonic',
        'minor_pentatonic',
    ]:
        try:
            synth, filename = scale_project(root_note, scale_name)
            filename = filename.replace('#', 's')
        except:
            print('***', root_note, scale_name)
        else:
            with open(filename, 'wb') as f:
                synth.write_to(f)
            print(':-)', filename)
            if root_note_id:
                filename = 'Transposed to C - {}'.format(filename)
                synth.module.project.in_mod.transpose = -root_note_id
                with open(filename, 'wb') as f:
                    synth.write_to(f)
# Out:
# :-) C major scale.sunsynth
# :-) C natural minor scale.sunsynth
# :-) C harmonic minor scale.sunsynth
# :-) C melodic minor scale.sunsynth
# :-) C dorian scale.sunsynth
# :-) C locrian scale.sunsynth
# :-) C lydian scale.sunsynth
# :-) C mixolydian scale.sunsynth
# :-) C phrygian scale.sunsynth
# :-) C major pentatonic scale.sunsynth
# :-) C minor pentatonic scale.sunsynth
# :-) Cs major scale.sunsynth
# :-) Cs natural minor scale.sunsynth
# :-) Cs harmonic minor scale.sunsynth
# :-) Cs melodic minor scale.sunsynth
# :-) Cs dorian scale.sunsynth
# :-) Cs locrian scale.sunsynth
# :-) Cs lydian scale.sunsynth
# :-) Cs mixolydian scale.sunsynth
# :-) Cs phrygian scale.sunsynth
# :-) Cs major pentatonic scale.sunsynth
# :-) Cs minor pentatonic scale.sunsynth
# :-) Db major scale.sunsynth
# *** Db natural_minor
# :-) Db harmonic minor scale.sunsynth
# :-) Db melodic minor scale.sunsynth
# *** Db dorian
# *** Db locrian
# :-) Db lydian scale.sunsynth
# *** Db mixolydian
# *** Db phrygian
# :-) Db major pentatonic scale.sunsynth
# *** Db minor_pentatonic
# :-) D major scale.sunsynth
# :-) D natural minor scale.sunsynth
# :-) D harmonic minor scale.sunsynth
# :-) D melodic minor scale.sunsynth
# :-) D dorian scale.sunsynth
# :-) D locrian scale.sunsynth
# :-) D lydian scale.sunsynth
# :-) D mixolydian scale.sunsynth
# :-) D phrygian scale.sunsynth
# :-) D major pentatonic scale.sunsynth
# :-) D minor pentatonic scale.sunsynth
# :-) Ds major scale.sunsynth
# :-) Ds natural minor scale.sunsynth
# :-) Ds harmonic minor scale.sunsynth
# :-) Ds melodic minor scale.sunsynth
# :-) Ds dorian scale.sunsynth
# :-) Ds locrian scale.sunsynth
# :-) Ds lydian scale.sunsynth
# :-) Ds mixolydian scale.sunsynth
# :-) Ds phrygian scale.sunsynth
# :-) Ds major pentatonic scale.sunsynth
# :-) Ds minor pentatonic scale.sunsynth
# :-) Eb major scale.sunsynth
# *** Eb natural_minor
# *** Eb harmonic_minor
# :-) Eb melodic minor scale.sunsynth
# :-) Eb dorian scale.sunsynth
# *** Eb locrian
# :-) Eb lydian scale.sunsynth
# :-) Eb mixolydian scale.sunsynth
# *** Eb phrygian
# :-) Eb major pentatonic scale.sunsynth
# :-) Eb minor pentatonic scale.sunsynth
# :-) E major scale.sunsynth
# :-) E natural minor scale.sunsynth
# :-) E harmonic minor scale.sunsynth
# :-) E melodic minor scale.sunsynth
# :-) E dorian scale.sunsynth
# :-) E locrian scale.sunsynth
# :-) E lydian scale.sunsynth
# :-) E mixolydian scale.sunsynth
# :-) E phrygian scale.sunsynth
# :-) E major pentatonic scale.sunsynth
# :-) E minor pentatonic scale.sunsynth
# :-) F major scale.sunsynth
# :-) F natural minor scale.sunsynth
# :-) F harmonic minor scale.sunsynth
# :-) F melodic minor scale.sunsynth
# :-) F dorian scale.sunsynth
# *** F locrian
# :-) F lydian scale.sunsynth
# :-) F mixolydian scale.sunsynth
# :-) F phrygian scale.sunsynth
# :-) F major pentatonic scale.sunsynth
# :-) F minor pentatonic scale.sunsynth
# :-) Fs major scale.sunsynth
# :-) Fs natural minor scale.sunsynth
# :-) Fs harmonic minor scale.sunsynth
# :-) Fs melodic minor scale.sunsynth
# :-) Fs dorian scale.sunsynth
# :-) Fs locrian scale.sunsynth
# :-) Fs lydian scale.sunsynth
# :-) Fs mixolydian scale.sunsynth
# :-) Fs phrygian scale.sunsynth
# :-) Fs major pentatonic scale.sunsynth
# :-) Fs minor pentatonic scale.sunsynth
# *** Gb major
# *** Gb natural_minor
# *** Gb harmonic_minor
# *** Gb melodic_minor
# *** Gb dorian
# *** Gb locrian
# :-) Gb lydian scale.sunsynth
# *** Gb mixolydian
# *** Gb phrygian
# :-) Gb major pentatonic scale.sunsynth
# *** Gb minor_pentatonic
# :-) G major scale.sunsynth
# :-) G natural minor scale.sunsynth
# :-) G harmonic minor scale.sunsynth
# :-) G melodic minor scale.sunsynth
# :-) G dorian scale.sunsynth
# :-) G locrian scale.sunsynth
# :-) G lydian scale.sunsynth
# :-) G mixolydian scale.sunsynth
# :-) G phrygian scale.sunsynth
# :-) G major pentatonic scale.sunsynth
# :-) G minor pentatonic scale.sunsynth
# :-) Gs major scale.sunsynth
# :-) Gs natural minor scale.sunsynth
# :-) Gs harmonic minor scale.sunsynth
# :-) Gs melodic minor scale.sunsynth
# :-) Gs dorian scale.sunsynth
# :-) Gs locrian scale.sunsynth
# :-) Gs lydian scale.sunsynth
# :-) Gs mixolydian scale.sunsynth
# :-) Gs phrygian scale.sunsynth
# :-) Gs major pentatonic scale.sunsynth
# :-) Gs minor pentatonic scale.sunsynth
# :-) Ab major scale.sunsynth
# :-) Ab natural minor scale.sunsynth
# :-) Ab harmonic minor scale.sunsynth
# :-) Ab melodic minor scale.sunsynth
# :-) Ab dorian scale.sunsynth
# :-) Ab locrian scale.sunsynth
# :-) Ab lydian scale.sunsynth
# :-) Ab mixolydian scale.sunsynth
# :-) Ab phrygian scale.sunsynth
# :-) Ab major pentatonic scale.sunsynth
# :-) Ab minor pentatonic scale.sunsynth
# :-) A major scale.sunsynth
# :-) A natural minor scale.sunsynth
# :-) A harmonic minor scale.sunsynth
# :-) A melodic minor scale.sunsynth
# :-) A dorian scale.sunsynth
# :-) A locrian scale.sunsynth
# :-) A lydian scale.sunsynth
# :-) A mixolydian scale.sunsynth
# :-) A phrygian scale.sunsynth
# :-) A major pentatonic scale.sunsynth
# :-) A minor pentatonic scale.sunsynth
# :-) As major scale.sunsynth
# :-) As natural minor scale.sunsynth
# :-) As harmonic minor scale.sunsynth
# :-) As melodic minor scale.sunsynth
# :-) As dorian scale.sunsynth
# :-) As locrian scale.sunsynth
# :-) As lydian scale.sunsynth
# :-) As mixolydian scale.sunsynth
# :-) As phrygian scale.sunsynth
# :-) As major pentatonic scale.sunsynth
# :-) As minor pentatonic scale.sunsynth
# :-) Bb major scale.sunsynth
# :-) Bb natural minor scale.sunsynth
# :-) Bb harmonic minor scale.sunsynth
# :-) Bb melodic minor scale.sunsynth
# :-) Bb dorian scale.sunsynth
# *** Bb locrian
# :-) Bb lydian scale.sunsynth
# :-) Bb mixolydian scale.sunsynth
# *** Bb phrygian
# :-) Bb major pentatonic scale.sunsynth
# :-) Bb minor pentatonic scale.sunsynth
# :-) B major scale.sunsynth
# :-) B natural minor scale.sunsynth
# :-) B harmonic minor scale.sunsynth
# :-) B melodic minor scale.sunsynth
# :-) B dorian scale.sunsynth
# :-) B locrian scale.sunsynth
# :-) B lydian scale.sunsynth
# :-) B mixolydian scale.sunsynth
# :-) B phrygian scale.sunsynth
# :-) B major pentatonic scale.sunsynth
# :-) B minor pentatonic scale.sunsynth
