# %% [markdown]
# # Scale generator for SunVox
#
# This is a series of note translators for SunVox that lock your notes
# into a specific scale.
#
# It requires SunVox 1.9.2 or higher to use effectively.
#
# ## How to use them
#
# In your existing project, use the "Merge project" command from the
# SunVox main menu, then select the scale you want to use.
#
# A chain of new modules will appear. You may wish to rearrange them
# to suit your needs.
#
# Connect the `O ...` module to the synth you want to send notes to.
# Then, send notes to the `I ...` module at the other side of the chain.
#
# ## How it works
#
# [*musthe*](https://github.com/gciruelos/musthe) provides a basic music theory engine. We maintain fork in the same directory as this notebook.
#
# [*Radiant Voices*](https://radiant-voices.readthedocs.io/) lets us construct and write SunVox compatible project files.
#
# The code below goes through all notes and scales available in *musthe*, and creates the structures needed to lock notes into those scales.

# %%
import musthe as m
import rv.api as rv

# %%
def scale_project(root_note, scale_name):
    name = '{} {} scale'.format(root_note, scale_name).replace('_', ' ')
    filename = '{}.sunvox'.format(name)
    
    scale = m.scale(m.Note(root_note), scale_name=scale_name)
    scale_ids = sorted({n.note_id for n in scale})
    
    proj = rv.Project()
    proj.name = name
    in_mod = proj.new_module(rv.m.MultiSynth, name='I {}'.format(name))
    in_mod.color = (0, 255, 0)
    out_mod = proj.new_module(rv.m.MultiSynth, name='O {}'.format(name))
    out_mod.color = (0, 0, 255)
    gate_mods = {}

    def gate_mod(offset):
        if offset not in gate_mods:
            gate = gate_mods[offset] = proj.new_module(
                rv.m.MultiSynth, 
                name='G{} {}'.format(offset, name),
            )
            gate.color = (64, 64, 64)
            if offset > 0:
                transpose = proj.new_module(
                    rv.m.MultiSynth,
                    name='T{} {}'.format(offset, name),
                    transpose=-offset,
                )
                transpose.color = (64, 64, 64)
                in_mod >> gate >> transpose >> out_mod
            else:
                in_mod >> gate >> out_mod
            for x in range(128):
                gate.nv_curve.values[x] = 0
        return gate_mods[offset]

    # Start one octave below to ensure offset is initialized
    # once we get to the note range we care about.
    offset = 0
    for note in range(-12, 128):
        if note % 12 in scale_ids:
            offset = 0
        else:
            offset += 1
        gate = gate_mod(offset)
        if note >= 0:
            gate.nv_curve.values[note] = 255

    proj.in_mod = in_mod
            
    proj.layout(prog='dot')            
    return proj, filename

# %%
for root_note in ['C', 'C#', 'Db', 'D', 'D#', 'Eb', 'E', 'F', 'F#', 'Gb', 'G', 'G#', 'Ab', 'A', 'A#', 'Bb', 'B']:
    root_note_id = m.Note(root_note).note_id
    for scale_name in [
        'major',
        'natural_minor',
        'harmonic_minor',
        'melodic_minor',
        'dorian',
        'locrian',
        'lydian',
        'mixolydian',
        'phrygian',
        'major_pentatonic',
        'minor_pentatonic',
    ]:
        try:
            proj, filename = scale_project(root_note, scale_name)
            filename = filename.replace('#', 's')
        except:
            print('***', root_note, scale_name)
        else:
            with open(filename, 'wb') as f:
                proj.write_to(f)
            print(':-)', filename)
            if root_note_id:
                filename = 'Transposed to C - {}'.format(filename)
                proj.in_mod.transpose = -root_note_id
                with open(filename, 'wb') as f:
                    proj.write_to(f)
# Out:
# :-) C major scale.sunvox
# :-) C natural minor scale.sunvox
# :-) C harmonic minor scale.sunvox
# :-) C melodic minor scale.sunvox
# :-) C dorian scale.sunvox
# :-) C locrian scale.sunvox
# :-) C lydian scale.sunvox
# :-) C mixolydian scale.sunvox
# :-) C phrygian scale.sunvox
# :-) C major pentatonic scale.sunvox
# :-) C minor pentatonic scale.sunvox
# :-) Cs major scale.sunvox
# :-) Cs natural minor scale.sunvox
# :-) Cs harmonic minor scale.sunvox
# :-) Cs melodic minor scale.sunvox
# :-) Cs dorian scale.sunvox
# :-) Cs locrian scale.sunvox
# :-) Cs lydian scale.sunvox
# :-) Cs mixolydian scale.sunvox
# :-) Cs phrygian scale.sunvox
# :-) Cs major pentatonic scale.sunvox
# :-) Cs minor pentatonic scale.sunvox
# :-) Db major scale.sunvox
# *** Db natural_minor
# :-) Db harmonic minor scale.sunvox
# :-) Db melodic minor scale.sunvox
# *** Db dorian
# *** Db locrian
# :-) Db lydian scale.sunvox
# *** Db mixolydian
# *** Db phrygian
# :-) Db major pentatonic scale.sunvox
# *** Db minor_pentatonic
# :-) D major scale.sunvox
# :-) D natural minor scale.sunvox
# :-) D harmonic minor scale.sunvox
# :-) D melodic minor scale.sunvox
# :-) D dorian scale.sunvox
# :-) D locrian scale.sunvox
# :-) D lydian scale.sunvox
# :-) D mixolydian scale.sunvox
# :-) D phrygian scale.sunvox
# :-) D major pentatonic scale.sunvox
# :-) D minor pentatonic scale.sunvox
# :-) Ds major scale.sunvox
# :-) Ds natural minor scale.sunvox
# :-) Ds harmonic minor scale.sunvox
# :-) Ds melodic minor scale.sunvox
# :-) Ds dorian scale.sunvox
# :-) Ds locrian scale.sunvox
# :-) Ds lydian scale.sunvox
# :-) Ds mixolydian scale.sunvox
# :-) Ds phrygian scale.sunvox
# :-) Ds major pentatonic scale.sunvox
# :-) Ds minor pentatonic scale.sunvox
# :-) Eb major scale.sunvox
# *** Eb natural_minor
# *** Eb harmonic_minor
# :-) Eb melodic minor scale.sunvox
# :-) Eb dorian scale.sunvox
# *** Eb locrian
# :-) Eb lydian scale.sunvox
# :-) Eb mixolydian scale.sunvox
# *** Eb phrygian
# :-) Eb major pentatonic scale.sunvox
# :-) Eb minor pentatonic scale.sunvox
# :-) E major scale.sunvox
# :-) E natural minor scale.sunvox
# :-) E harmonic minor scale.sunvox
# :-) E melodic minor scale.sunvox
# :-) E dorian scale.sunvox
# :-) E locrian scale.sunvox
# :-) E lydian scale.sunvox
# :-) E mixolydian scale.sunvox
# :-) E phrygian scale.sunvox
# :-) E major pentatonic scale.sunvox
# :-) E minor pentatonic scale.sunvox
# :-) F major scale.sunvox
# :-) F natural minor scale.sunvox
# :-) F harmonic minor scale.sunvox
# :-) F melodic minor scale.sunvox
# :-) F dorian scale.sunvox
# *** F locrian
# :-) F lydian scale.sunvox
# :-) F mixolydian scale.sunvox
# :-) F phrygian scale.sunvox
# :-) F major pentatonic scale.sunvox
# :-) F minor pentatonic scale.sunvox
# :-) Fs major scale.sunvox
# :-) Fs natural minor scale.sunvox
# :-) Fs harmonic minor scale.sunvox
# :-) Fs melodic minor scale.sunvox
# :-) Fs dorian scale.sunvox
# :-) Fs locrian scale.sunvox
# :-) Fs lydian scale.sunvox
# :-) Fs mixolydian scale.sunvox
# :-) Fs phrygian scale.sunvox
# :-) Fs major pentatonic scale.sunvox
# :-) Fs minor pentatonic scale.sunvox
# *** Gb major
# *** Gb natural_minor
# *** Gb harmonic_minor
# *** Gb melodic_minor
# *** Gb dorian
# *** Gb locrian
# :-) Gb lydian scale.sunvox
# *** Gb mixolydian
# *** Gb phrygian
# :-) Gb major pentatonic scale.sunvox
# *** Gb minor_pentatonic
# :-) G major scale.sunvox
# :-) G natural minor scale.sunvox
# :-) G harmonic minor scale.sunvox
# :-) G melodic minor scale.sunvox
# :-) G dorian scale.sunvox
# :-) G locrian scale.sunvox
# :-) G lydian scale.sunvox
# :-) G mixolydian scale.sunvox
# :-) G phrygian scale.sunvox
# :-) G major pentatonic scale.sunvox
# :-) G minor pentatonic scale.sunvox
# :-) Gs major scale.sunvox
# :-) Gs natural minor scale.sunvox
# :-) Gs harmonic minor scale.sunvox
# :-) Gs melodic minor scale.sunvox
# :-) Gs dorian scale.sunvox
# :-) Gs locrian scale.sunvox
# :-) Gs lydian scale.sunvox
# :-) Gs mixolydian scale.sunvox
# :-) Gs phrygian scale.sunvox
# :-) Gs major pentatonic scale.sunvox
# :-) Gs minor pentatonic scale.sunvox
# :-) Ab major scale.sunvox
# :-) Ab natural minor scale.sunvox
# :-) Ab harmonic minor scale.sunvox
# :-) Ab melodic minor scale.sunvox
# :-) Ab dorian scale.sunvox
# :-) Ab locrian scale.sunvox
# :-) Ab lydian scale.sunvox
# :-) Ab mixolydian scale.sunvox
# :-) Ab phrygian scale.sunvox
# :-) Ab major pentatonic scale.sunvox
# :-) Ab minor pentatonic scale.sunvox
# :-) A major scale.sunvox
# :-) A natural minor scale.sunvox
# :-) A harmonic minor scale.sunvox
# :-) A melodic minor scale.sunvox
# :-) A dorian scale.sunvox
# :-) A locrian scale.sunvox
# :-) A lydian scale.sunvox
# :-) A mixolydian scale.sunvox
# :-) A phrygian scale.sunvox
# :-) A major pentatonic scale.sunvox
# :-) A minor pentatonic scale.sunvox
# :-) As major scale.sunvox
# :-) As natural minor scale.sunvox
# :-) As harmonic minor scale.sunvox
# :-) As melodic minor scale.sunvox
# :-) As dorian scale.sunvox
# :-) As locrian scale.sunvox
# :-) As lydian scale.sunvox
# :-) As mixolydian scale.sunvox
# :-) As phrygian scale.sunvox
# :-) As major pentatonic scale.sunvox
# :-) As minor pentatonic scale.sunvox
# :-) Bb major scale.sunvox
# :-) Bb natural minor scale.sunvox
# :-) Bb harmonic minor scale.sunvox
# :-) Bb melodic minor scale.sunvox
# :-) Bb dorian scale.sunvox
# *** Bb locrian
# :-) Bb lydian scale.sunvox
# :-) Bb mixolydian scale.sunvox
# *** Bb phrygian
# :-) Bb major pentatonic scale.sunvox
# :-) Bb minor pentatonic scale.sunvox
# :-) B major scale.sunvox
# :-) B natural minor scale.sunvox
# :-) B harmonic minor scale.sunvox
# :-) B melodic minor scale.sunvox
# :-) B dorian scale.sunvox
# :-) B locrian scale.sunvox
# :-) B lydian scale.sunvox
# :-) B mixolydian scale.sunvox
# :-) B phrygian scale.sunvox
# :-) B major pentatonic scale.sunvox
# :-) B minor pentatonic scale.sunvox
